# %%
import pandas as pd
import json

X_test = pd.read_json('data/X_test_sample_1.json', lines=True)
X_test
# Out:
#    total_deposit  total_handle  total_ngr  months_active  brand_id_AZ  \
# 0              0          0.00       0.00              4        False
# 1              0          0.00       0.00             16        False
# 2            330       5619.20     -47.82              2        False
# 3              0          0.00       0.00             16        False
# 4              0          0.00       0.00              3        False
# 5              0          0.00       0.00              7        False
# 6              0        119.59      12.43              7        False
# 7              0          0.00       0.00              0        False
# 8             30         20.00      17.34              5        False
# 9              0         79.50     -15.54              8        False
#
#    brand_id_CA  brand_id_CO  brand_id_DC  brand_id_ER  brand_id_GM  ...  \
# 0        False        False        False        False         True  ...
# ...

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 45 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   total_deposit                10 non-null     int64
#  1   total_handle                 10 non-null     float64
#  2   total_ngr                    10 non-null     float64
#  3   months_active                10 non-null     int64
#  4   brand_id_AZ                  10 non-null     bool
#  5   brand_id_CA                  10 non-null     bool
#  6   brand_id_CO                  10 non-null     bool
#  7   brand_id_DC                  10 non-null     bool
#  8   brand_id_ER                  10 non-null     bool
#  9   brand_id_GM                  10 non-null     bool
#  10  brand_id_IA                  10 non-null     bool
#  11  brand_id_IN                  10 non-null     bool
#  12  brand_id_IS                  10 non-null     bool
# ...

# %%
with open('data/feature_names_1.json', 'r') as f:
    feature_names = json.load(f)

feature_names
# Out:
# ['total_deposit',
#  'total_handle',
#  'total_ngr',
#  'months_active',
#  'brand_id_AZ',
#  'brand_id_CA',
#  'brand_id_CO',
#  'brand_id_DC',
#  'brand_id_ER',
#  'brand_id_GM',
#  'brand_id_IA',
#  'brand_id_IN',
#  'brand_id_IS',
#  'brand_id_KS',
#  'brand_id_KY',
#  'brand_id_LA',
#  'brand_id_MA',
#  'brand_id_MD',
#  'brand_id_MI',
#  'brand_id_MS',
#  'brand_id_NC',
#  'brand_id_NE',
#  'brand_id_NJ',
#  'brand_id_NO',
#  'brand_id_NV',
#  'brand_id_NY',
#  'brand_id_OH',
#  'brand_id_PA',
#  'brand_id_TN',
#  'brand_id_US',
#  'brand_id_VA',
#  'brand_id_WV',
#  'brand_id_WY',
#  'ben_login_id_BCCSB22',
#  'ben_login_id_BCUSA22L',
#  'ben_login_id_BCUSA22N',
#  'ben_login_id_BCUSA22NP',
#  'ben_login_id_actionnetwork',
#  'ben_login_id_starsportsmx',
#  'ben_login_id_wedgetraffic',
#  'player_reg_product_BETTING',
#  'player_reg_product_BINGO',
#  'player_reg_product_CASINO',
#  'player_reg_product_POKER',
#  'player_reg_product_RACEBOOK']

# %%
X_test[feature_names]
# Out:
#    total_deposit  total_handle  total_ngr  months_active  brand_id_AZ  \
# 0              0          0.00       0.00              4        False
# 1              0          0.00       0.00             16        False
# 2            330       5619.20     -47.82              2        False
# 3              0          0.00       0.00             16        False
# 4              0          0.00       0.00              3        False
# 5              0          0.00       0.00              7        False
# 6              0        119.59      12.43              7        False
# 7              0          0.00       0.00              0        False
# 8             30         20.00      17.34              5        False
# 9              0         79.50     -15.54              8        False
#
#    brand_id_CA  brand_id_CO  brand_id_DC  brand_id_ER  brand_id_GM  ...  \
# 0        False        False        False        False         True  ...
# ...
